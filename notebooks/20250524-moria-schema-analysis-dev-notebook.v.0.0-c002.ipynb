# %%
import sys
import os

# Add the project directory to sys.path
project_path = "/Users/hugocontrerasp/Documents/MORIA_AI_LABS/moria_data_readiness_engine"
if project_path not in sys.path:
    sys.path.append(project_path)

# %%
# Import the function
from moria_engine.analysis.data_transformers import build_common_fields_matrix_schema
from moria_engine.analysis import graph_visualizer,graph_explainer
from moria_engine.data import loaders
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pyvis.network import Network
import networkx as nx

df = loaders.load_json_schema('../data/test/c002_prancing_pony/20250525-hacp-c002_prancing_pony-data_domains_schema.json')

# %%
from IPython.display import display, HTML

# %%
M, table_list, d_table_domain, G = build_common_fields_matrix_schema(df)

# %%
graph_visualizer.visualize_network_schema(df)

# %%
#graph_visualizer.visualize_network_interactive(df)

# %%
graph_explainer.graph_centrality_attributes(df)
# Out:
#                    node domain_name  degree  centrality  \
# 0   CustomerPreferences    Customer       2    0.166667
# 1             Customers    Customer       5    0.416667
# 2     EmployeeSchedules    Employee       1    0.083333
# 3             Employees    Employee       5    0.416667
# 4           Ingredients        Menu       3    0.250000
# 5             Inventory   Inventory       5    0.416667
# 6             Locations    Location       5    0.416667
# 7   MenuItemIngredients        Menu       4    0.333333
# 8             MenuItems        Menu       2    0.166667
# 9            OrderItems       Order       4    0.333333
# 10               Orders       Order       7    0.583333
# 11             Payments       Order       2    0.166667
# 12            Suppliers    Supplier       3    0.250000
#
#     betweenness_centrality
# 0                 0.000000
# 1                 0.080808
# 2                 0.000000
# 3                 0.174747
# 4                 0.045960
# 5                 0.160606
# 6                 0.051010
# 7                 0.103535
# 8                 0.000000
# 9                 0.124242
# 10                0.331818
# 11                0.000000
# 12                0.033333

# %%
print(graph_explainer.graph_centrality_narrative(df))
# Out:
# Graph Centrality Analysis:
#
# Node 'CustomerPreferences' in domain 'Customer' has:
# - Degree: 2
# - Centrality: 0.1667
# - Betweenness Centrality: 0.0000
#
# Node 'Customers' in domain 'Customer' has:
# - Degree: 5
# - Centrality: 0.4167
# - Betweenness Centrality: 0.0808
#
# Node 'EmployeeSchedules' in domain 'Employee' has:
# - Degree: 1
# - Centrality: 0.0833
# - Betweenness Centrality: 0.0000
#
# Node 'Employees' in domain 'Employee' has:
# - Degree: 5
# - Centrality: 0.4167
# - Betweenness Centrality: 0.1747
#
# Node 'Ingredients' in domain 'Menu' has:
# - Degree: 3
# - Centrality: 0.2500
# - Betweenness Centrality: 0.0460
#
# Node 'Inventory' in domain 'Inventory' has:
# - Degree: 5
# - Centrality: 0.4167
# - Betweenness Centrality: 0.1606
#
# Node 'Locations' in domain 'Location' has:
# - Degree: 5
# - Centrality: 0.4167
# - Betweenness Centrality: 0.0510
#
# Node 'MenuItemIngredients' in domain 'Menu' has:
# - Degree: 4
# - Centrality: 0.3333
# - Betweenness Centrality: 0.1035
#
# Node 'MenuItems' in domain 'Menu' has:
# - Degree: 2
# - Centrality: 0.1667
# - Betweenness Centrality: 0.0000
#
# Node 'OrderItems' in domain 'Order' has:
# - Degree: 4
# - Centrality: 0.3333
# - Betweenness Centrality: 0.1242
#
# Node 'Orders' in domain 'Order' has:
# - Degree: 7
# - Centrality: 0.5833
# - Betweenness Centrality: 0.3318
#
# Node 'Payments' in domain 'Order' has:
# - Degree: 2
# - Centrality: 0.1667
# - Betweenness Centrality: 0.0000
#
# Node 'Suppliers' in domain 'Supplier' has:
# - Degree: 3
# - Centrality: 0.2500
# - Betweenness Centrality: 0.0333

# %%
print(graph_explainer.graph_centrality_summary_warning(df))
# Out:
# Graph Centrality Summary Warning:
#
#
#
# This analysis helps identify key nodes in the graph that may have significant influence on the overall structure and relationships.
#
# The following nodes have been analyzed based on their centrality measures:
#
# Warning: The following nodes have high centrality values, indicating potential key roles in the graph. High impact to the whole network if there is a failure or severe quality issues in the node:
# - Node 'Orders' in domain 'Order' with Centrality: 0.5833
#
#
# Warning: The following nodes have low betweenness centrality values, indicating potential isolation/low data quality. Low impact to the whole network if there is a failure or severe quality issues in the node:
# - Node 'CustomerPreferences' in domain 'Customer' with Betweenness Centrality: 0.0000
# - Node 'EmployeeSchedules' in domain 'Employee' with Betweenness Centrality: 0.0000
# - Node 'Ingredients' in domain 'Menu' with Betweenness Centrality: 0.0460
# - Node 'MenuItems' in domain 'Menu' with Betweenness Centrality: 0.0000
# - Node 'Payments' in domain 'Order' with Betweenness Centrality: 0.0000
# - Node 'Suppliers' in domain 'Supplier' with Betweenness Centrality: 0.0333
#
# Please review the graph for potential key nodes and their relationships.
