# %%
import sys
import os

# Add the project directory to sys.path
project_path = "/Users/hugocontrerasp/Documents/MORIA_AI_LABS/moria_data_readiness_engine"
if project_path not in sys.path:
    sys.path.append(project_path)

# %%
# Import the function
from moria_engine.analysis.data_transformers import build_common_fields_matrix_kpis, build_common_fields_matrix_schema
from moria_engine.analysis import graph_visualizer,graph_explainer
from moria_engine.data import loaders
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pyvis.network import Network
import networkx as nx

df_kpis = loaders.load_json_kpis('../data/test/c001_bamfurlong/20250524-hacp-c001_bamfurlong-kpi_details.json')
df_schema = loaders.load_json_schema('../data/test/c001_bamfurlong/20250524-hacp-c001_bamfurlong-data_domains_schema.json')

# %%
df_kpis.head()
# Out:
#                     kpi_name domain_name  table_name   field_name
# 0              Total Revenue       Sales  SalesOrder  TotalAmount
# 1  Monthly Recurring Revenue       Sales  SalesOrder  TotalAmount
# 2  Monthly Recurring Revenue       Sales  SalesOrder    OrderDate
# 3        Average Order Value       Sales  SalesOrder  TotalAmount
# 4        Average Order Value       Sales  SalesOrder      OrderID

# %%
df_schema.head()
# Out:
#   domain_name table_name   field_name
# 0    Customer   Customer   CustomerID
# 1    Customer   Customer    FirstName
# 2    Customer   Customer     LastName
# 3    Customer   Customer        Email
# 4    Customer   Customer  PhoneNumber

# %%
M, table_list, d_table_domain, G = build_common_fields_matrix_kpis(df_kpis)

# %%
graph_visualizer.visualize_network_kpis(df_kpis)

# %%
graph_visualizer.visualize_network_schema(df_schema)

# %%
graph_visualizer.visualize_combined_networks1(df_schema, df_kpis)

# %%
graph_explainer.graph_centrality_attributes(df_kpis)
# Out:
#           node domain_name  degree  centrality  betweenness_centrality
# 0     Category     Product       1    0.142857                0.000000
# 1     Customer    Customer       1    0.142857                0.000000
# 2    GLAccount     Finance       0    0.000000                0.000000
# 3    Inventory   Inventory       2    0.285714                0.000000
# 4    OrderItem       Sales       2    0.285714                0.000000
# 5      Product     Product       3    0.428571                0.095238
# 6   SalesOrder       Sales       1    0.142857                0.000000
# 7  Transaction     Finance       0    0.000000                0.000000

# %%
graph_explainer.graph_centrality_attributes(df_schema)
# Out:
#           node domain_name  degree  centrality  betweenness_centrality
# 0      Address    Customer       2    0.222222                0.000000
# 1     Category     Product       1    0.111111                0.000000
# 2     Customer    Customer       3    0.333333                0.152778
# 3    GLAccount     Finance       1    0.111111                0.000000
# 4    Inventory   Inventory       3    0.333333                0.208333
# 5     Location   Inventory       3    0.333333                0.152778
# 6    OrderItem       Sales       4    0.444444                0.305556
# 7      Product     Product       3    0.333333                0.222222
# 8   SalesOrder       Sales       3    0.333333                0.208333
# 9  Transaction     Finance       3    0.333333                0.222222

# %%
df_schema['table_name'].unique()
# Out:
# array(['Customer', 'Address', 'Product', 'Category', 'SalesOrder',
#        'OrderItem', 'Inventory', 'Location', 'Transaction', 'GLAccount'],
#       dtype=object)

# %%
df_kpis['table_name'].unique()
# Out:
# array(['SalesOrder', 'Transaction', 'Customer', 'Inventory', 'OrderItem',
#        'GLAccount', 'Product', 'Category'], dtype=object)

# %%
M_kpis, table_list_kpis, d_table_domain_kpis, G_kpis = build_common_fields_matrix_kpis(df_kpis)

# %%
M_schema, table_list_schema, d_table_domain_schema, G_schema = build_common_fields_matrix_schema(df_schema)

# %%
G_kpis
# Out:
# {'Category': ['Sales by Product Category', 'Sales by Product Category'],
#  'Customer': ['Customer Acquisition Cost (CAC)',
#   'Customer Acquisition Cost (CAC)',
#   'Customer Lifetime Value (CLTV)',
#   'Customer Retention Rate',
#   'Customer Satisfaction Score (CSAT)'],
#  'GLAccount': ['Gross Profit Margin',
#   'Gross Profit Margin',
#   'Net Profit Margin',
#   'Net Profit Margin',
#   'Return on Assets (ROA)',
#   'Return on Assets (ROA)'],
#  'Inventory': ['Inventory Turnover Ratio',
#   'Inventory Turnover Ratio',
#   'Stockout Rate',
#   'Stockout Rate'],
#  'OrderItem': ['Inventory Turnover Ratio',
#   'Inventory Turnover Ratio',
#   'Stockout Rate',
#   'Stockout Rate',
#   'Defect Rate',
#   'Defect Rate',
#   'Sales by Product Category',
#   'Sales by Product Category',
#   'Sales by Product Category'],
#  'Product': ['Sales by Product Category', 'Sales by Product Category'],
#  'SalesOrder': ['Total Revenue',
#   'Monthly Recurring Revenue',
#   'Monthly Recurring Revenue',
#   'Average Order Value',
#   'Average Order Value',
#   'Number of Orders',
#   'Number of Orders',
#   'Customer Lifetime Value (CLTV)',
#   'Customer Lifetime Value (CLTV)',
#   'Customer Lifetime Value (CLTV)',
#   'Customer Retention Rate',
#   'Order Fulfillment Time',
#   'Order Fulfillment Time',
#   'Order Fulfillment Time'],
#  'Transaction': ['Customer Acquisition Cost (CAC)',
#   'Customer Acquisition Cost (CAC)',
#   'Customer Lifetime Value (CLTV)',
#   'Customer Lifetime Value (CLTV)',
#   'Gross Profit Margin',
#   'Gross Profit Margin',
#   'Net Profit Margin',
#   'Net Profit Margin',
#   'Return on Assets (ROA)',
#   'Return on Assets (ROA)']}

# %%
nx.graph_edit_distance(G_schema, G_kpis)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 nx.graph_edit_distance(G_schema, G_kpis)
#
# File ~/Documents/GitHub/moria_ai_labs_dev/data_readiness/venv_mal_data_readiness/lib/python3.11/site-packages/networkx/utils/decorators.py:788, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     787 def func(*args, __wrapper=None, **kwargs):
# --> 788     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 75:3, in argmap_graph_edit_distance_72(G1, G2, node_match, edge_match, node_subst_cost, node_del_cost, node_ins_cost, edge_subst_cost, edge_del_cost, edge_ins_cost, roots, upper_bound, timeout, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/Documents/GitHub/moria_ai_labs_dev/data_readiness/venv_mal_data_readiness/lib/python3.11/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~/Documents/GitHub/moria_ai_labs_dev/data_readiness/venv_mal_data_readiness/lib/python3.11/site-packages/networkx/algorithms/similarity.py:193, in graph_edit_distance(G1, G2, node_match, edge_match, node_subst_cost, node_del_cost, node_ins_cost, edge_subst_cost, edge_del_cost, edge_ins_cost, roots, upper_bound, timeout)
#      58 """Returns GED (graph edit distance) between graphs G1 and G2.
#      59
#      60 Graph edit distance is a graph similarity measure analogous to
#    (...)    190
#     191 """
#     192 bestcost = None
# --> 193 for _, _, cost in optimize_edit_paths(
#     194     G1,
#     195     G2,
#     196     node_match,
#     197     edge_match,
#     198     node_subst_cost,
#     199     node_del_cost,
#     200     node_ins_cost,
#     201     edge_subst_cost,
#     202     edge_del_cost,
#     203     edge_ins_cost,
#     204     upper_bound,
#     205     True,
#     206     roots,
#     207     timeout,
#     208 ):
#     209     # assert bestcost is None or cost < bestcost
#     210     bestcost = cost
#     211 return bestcost
#
# File ~/Documents/GitHub/moria_ai_labs_dev/data_readiness/venv_mal_data_readiness/lib/python3.11/site-packages/networkx/algorithms/similarity.py:1073, in optimize_edit_paths(G1, G2, node_match, edge_match, node_subst_cost, node_del_cost, node_ins_cost, edge_subst_cost, edge_del_cost, edge_ins_cost, upper_bound, strictly_decreasing, roots, timeout)
#    1070 # Initialization
#    1072 pending_u = list(G1.nodes)
# -> 1073 pending_v = list(G2.nodes)
#    1075 initial_cost = 0
#    1076 if roots:
#
# AttributeError: 'dict' object has no attribute 'nodes'
