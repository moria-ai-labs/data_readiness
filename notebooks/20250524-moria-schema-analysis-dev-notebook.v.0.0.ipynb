# %%
import sys
import os

# Add the project directory to sys.path
project_path = "/Users/hugocontrerasp/Documents/MORIA_AI_LABS/moria_data_readiness_engine"
if project_path not in sys.path:
    sys.path.append(project_path)

# %%
# Import the function
from moria_engine.analysis.data_transformers import build_common_fields_matrix_schema
from moria_engine.analysis import graph_visualizer,graph_explainer
from moria_engine.data import loaders
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pyvis.network import Network
import networkx as nx

df = loaders.load_json_schema('../data/test/20250520-hacp-company-data_domains_schema.json')

# %%
from IPython.display import display, HTML

# %%
M, table_list, d_table_domain, G = build_common_fields_matrix_schema(df)

# %%
graph_visualizer.visualize_network_schema(df)

# %%
#graph_visualizer.visualize_network_interactive(df)

# %%
graph_explainer.graph_centrality_attributes(df)
# Out:
#                       node domain_name  degree  centrality  \
# 0                Campaigns   Marketing       3    0.250000
# 1               Categories     Product       2    0.166667
# 2            CustomerTypes    Customer       1    0.083333
# 3       Customer_Campaigns   Marketing       5    0.416667
# 4   Customer_CustomerTypes    Customer       5    0.416667
# 5                Customers    Customer       6    0.500000
# 6                Employees    Employee       4    0.333333
# 7             OrderDetails       Sales       4    0.333333
# 8                   Orders       Sales       7    0.583333
# 9                 Payments       Sales       2    0.166667
# 10                Products     Product       5    0.416667
# 11            ServiceCalls     Service       7    0.583333
# 12               Suppliers     Product       3    0.250000
#
#     betweenness_centrality
# 0                 0.047980
# 1                 0.000000
# 2                 0.000000
# 3                 0.110101
# 4                 0.166667
# 5                 0.081313
# 6                 0.017677
# 7                 0.063131
# 8                 0.157071
# 9                 0.000000
# 10                0.187879
# 11                0.152525
# 12                0.030808

# %%
print(graph_explainer.graph_centrality_narrative(df))
# Out:
# Graph Centrality Analysis:
#
# Node 'Campaigns' in domain 'Marketing' has:
# - Degree: 3
# - Centrality: 0.2500
# - Betweenness Centrality: 0.0480
#
# Node 'Categories' in domain 'Product' has:
# - Degree: 2
# - Centrality: 0.1667
# - Betweenness Centrality: 0.0000
#
# Node 'CustomerTypes' in domain 'Customer' has:
# - Degree: 1
# - Centrality: 0.0833
# - Betweenness Centrality: 0.0000
#
# Node 'Customer_Campaigns' in domain 'Marketing' has:
# - Degree: 5
# - Centrality: 0.4167
# - Betweenness Centrality: 0.1101
#
# Node 'Customer_CustomerTypes' in domain 'Customer' has:
# - Degree: 5
# - Centrality: 0.4167
# - Betweenness Centrality: 0.1667
#
# Node 'Customers' in domain 'Customer' has:
# - Degree: 6
# - Centrality: 0.5000
# - Betweenness Centrality: 0.0813
#
# Node 'Employees' in domain 'Employee' has:
# - Degree: 4
# - Centrality: 0.3333
# - Betweenness Centrality: 0.0177
#
# Node 'OrderDetails' in domain 'Sales' has:
# - Degree: 4
# - Centrality: 0.3333
# - Betweenness Centrality: 0.0631
#
# Node 'Orders' in domain 'Sales' has:
# - Degree: 7
# - Centrality: 0.5833
# - Betweenness Centrality: 0.1571
#
# Node 'Payments' in domain 'Sales' has:
# - Degree: 2
# - Centrality: 0.1667
# - Betweenness Centrality: 0.0000
#
# Node 'Products' in domain 'Product' has:
# - Degree: 5
# - Centrality: 0.4167
# - Betweenness Centrality: 0.1879
#
# Node 'ServiceCalls' in domain 'Service' has:
# - Degree: 7
# - Centrality: 0.5833
# - Betweenness Centrality: 0.1525
#
# Node 'Suppliers' in domain 'Product' has:
# - Degree: 3
# - Centrality: 0.2500
# - Betweenness Centrality: 0.0308

# %%
print(graph_explainer.graph_centrality_summary_warning(df))
# Out:
# Graph Centrality Summary Warning:
#
#
#
# This analysis helps identify key nodes in the graph that may have significant influence on the overall structure and relationships.
#
# The following nodes have been analyzed based on their centrality measures:
#
# Warning: The following nodes have high centrality values, indicating potential key roles in the graph. High impact to the whole network if there is a failure or severe quality issues in the node:
# - Node 'Orders' in domain 'Sales' with Centrality: 0.5833
# - Node 'ServiceCalls' in domain 'Service' with Centrality: 0.5833
#
#
# Warning: The following nodes have low betweenness centrality values, indicating potential isolation/low data quality. Low impact to the whole network if there is a failure or severe quality issues in the node:
# - Node 'Campaigns' in domain 'Marketing' with Betweenness Centrality: 0.0480
# - Node 'Categories' in domain 'Product' with Betweenness Centrality: 0.0000
# - Node 'CustomerTypes' in domain 'Customer' with Betweenness Centrality: 0.0000
# - Node 'Employees' in domain 'Employee' with Betweenness Centrality: 0.0177
# - Node 'Payments' in domain 'Sales' with Betweenness Centrality: 0.0000
# - Node 'Suppliers' in domain 'Product' with Betweenness Centrality: 0.0308
#
# Please review the graph for potential key nodes and their relationships.
